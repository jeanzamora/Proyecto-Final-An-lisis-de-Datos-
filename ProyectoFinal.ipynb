# %% [markdown]
# <p style="text-align: right"> 29/12/2023</p>
#
# <title>Análisis de Datos</title>
# <p>PK2 Company</p>
# <p>2021-2022</p>
#
# <span style="font-size: 70px; text-align: center; display: block; margin: 0 auto; ">Proyecto</span>
# <span style="font-size: 40px; text-align: center; display: block; margin: 0 auto;background-color:rgb(255, 155, 71);"> Venta de Bienes Raíces</span>
#
# <img src="BienesyRaices.jpg" alt="Trulli" width="500" height="333" style="display: block; margin: 0 auto;">
#
# <p style="text-align: right">Jean Carlo Zamora Alfaro </p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dfData = pd.read_excel("data.xlsx")

# %%
print(dfData.head())
# Out:
#    Serial Number  List Year Date Recorded     Town                Address  \
# 0      2020348.0     2020.0    09/13/2021  Ansonia        230 WAKELEE AVE
# 1        20002.0     2020.0    10/02/2020  Ashford        390 TURNPIKE RD
# 2       200212.0     2020.0    03/09/2021     Avon       5 CHESTNUT DRIVE
# 3       200243.0     2020.0    04/13/2021     Avon  111 NORTHINGTON DRIVE
# 4       200377.0     2020.0    07/02/2021     Avon     70 FAR HILLS DRIVE
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 0      15050000.0   32500000.0        463.0    Commercial              NaN
# 1      25300000.0   43000000.0       5883.0   Residential    Single Family
# 2      13040000.0   17990000.0       7248.0   Residential            Condo
# 3      61929000.0   89000000.0       6958.0   Residential    Single Family
# 4      86233000.0  144750000.0       5957.0   Residential    Single Family
#
#   Non Use Code Assessor Remarks OPM remarks
# ...

# %%
dfData.head(16)
# Out:
#     Serial Number  List Year Date Recorded        Town                Address  \
# 0       2020348.0     2020.0    09/13/2021     Ansonia        230 WAKELEE AVE
# 1         20002.0     2020.0    10/02/2020     Ashford        390 TURNPIKE RD
# 2        200212.0     2020.0    03/09/2021        Avon       5 CHESTNUT DRIVE
# 3        200243.0     2020.0    04/13/2021        Avon  111 NORTHINGTON DRIVE
# 4        200377.0     2020.0    07/02/2021        Avon     70 FAR HILLS DRIVE
# 5        200109.0     2020.0    12/09/2020        Avon     57 FAR HILLS DRIVE
# 6       2020180.0     2020.0    03/01/2021      Berlin    1539 FARMINGTON AVE
# 7       2020313.0     2020.0    07/01/2021      Berlin      216 WATCH HILL RD
# 8        200097.0     2020.0    06/04/2021     Bethany            23 AMITY RD
# 9         20139.0     2020.0    12/16/2020      Bethel      16 DEEPWOOD DRIVE
# 10       200086.0     2020.0    08/10/2021   Bethlehem         39 WOODLAND RD
# ...

# %%
dfData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200336 entries, 0 to 200335
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Serial Number     200334 non-null  float64
#  1   List Year         199998 non-null  float64
#  2   Date Recorded     199996 non-null  object
#  3   Town              199998 non-null  object
#  4   Address           199994 non-null  object
#  5   Assessed Value    199993 non-null  float64
#  6   Sale Amount       199993 non-null  float64
#  7   Sales Ratio       199993 non-null  float64
#  8   Property Type     66783 non-null   object
#  9   Residential Type  60935 non-null   object
#  10  Non Use Code      45747 non-null   object
#  11  Assessor Remarks  14344 non-null   object
#  12  OPM remarks       1981 non-null    object
# dtypes: float64(5), object(8)
# memory usage: 19.9+ MB

# %%
dfData.head(8760)
# Out:
#       Serial Number  List Year Date Recorded           Town  \
# 0         2020348.0     2020.0    09/13/2021        Ansonia
# 1           20002.0     2020.0    10/02/2020        Ashford
# 2          200212.0     2020.0    03/09/2021           Avon
# 3          200243.0     2020.0    04/13/2021           Avon
# 4          200377.0     2020.0    07/02/2021           Avon
# ...             ...        ...           ...            ...
# 8755       200002.0     2020.0    10/05/2020        Bethany
# 8756       200358.0     2020.0    07/12/2021      Killingly
# 8757       201259.0     2020.0    09/27/2021       Hartford
# 8758       200091.0     2020.0    05/27/2021        Bethany
# 8759        20726.0     2020.0    07/15/2021  East Hartford
#
#                              Address  Assessed Value  Sale Amount  \
# 0                    230 WAKELEE AVE      15050000.0   32500000.0
# 1                    390 TURNPIKE RD      25300000.0   43000000.0
# ...

# %%
dfData.rename({'Serial Number':'SerialNumber'}, axis=1, inplace=True)
dfData.rename({'List Year':'ListYear'}, axis=1, inplace=True)
dfData.rename({'Date Recorded':'DateRecorded'}, axis=1, inplace=True)
dfData.rename({'Assessed Value':'AssessedValue'}, axis=1, inplace=True)
dfData.rename({'Sale Amount':'SaleAmount'}, axis=1, inplace=True)
dfData.rename({'Sales Ratio':'SalesRatio'}, axis=1, inplace=True)
dfData.rename({'Property Type':'PropertyType'}, axis=1, inplace=True)
dfData.rename({'Residential Type':'ResidentialType'}, axis=1, inplace=True)
dfData.rename({'Non Use Code':'NonUseCode'}, axis=1, inplace=True)
dfData.rename({'Assessor Remarks':'AssessorRemarks'}, axis=1, inplace=True)
dfData.rename({'OPM remarks':'OPMremarks'}, axis=1, inplace=True)

# %%
dfData.head(8760)
# Out:
#       SerialNumber  ListYear DateRecorded           Town  \
# 0        2020348.0    2020.0   09/13/2021        Ansonia
# 1          20002.0    2020.0   10/02/2020        Ashford
# 2         200212.0    2020.0   03/09/2021           Avon
# 3         200243.0    2020.0   04/13/2021           Avon
# 4         200377.0    2020.0   07/02/2021           Avon
# ...            ...       ...          ...            ...
# 8755      200002.0    2020.0   10/05/2020        Bethany
# 8756      200358.0    2020.0   07/12/2021      Killingly
# 8757      201259.0    2020.0   09/27/2021       Hartford
# 8758      200091.0    2020.0   05/27/2021        Bethany
# 8759       20726.0    2020.0   07/15/2021  East Hartford
#
#                              Address  AssessedValue   SaleAmount  SalesRatio  \
# 0                    230 WAKELEE AVE     15050000.0   32500000.0       463.0
# 1                    390 TURNPIKE RD     25300000.0   43000000.0      5883.0
# ...

# %%
dfData.dropna(subset = ['ListYear'], axis=0, inplace=True)
dfData.reset_index(drop = True, inplace=True)

# %%
dfData.head(8760)
# Out:
#       SerialNumber  ListYear DateRecorded           Town  \
# 0        2020348.0    2020.0   09/13/2021        Ansonia
# 1          20002.0    2020.0   10/02/2020        Ashford
# 2         200212.0    2020.0   03/09/2021           Avon
# 3         200243.0    2020.0   04/13/2021           Avon
# 4         200377.0    2020.0   07/02/2021           Avon
# ...            ...       ...          ...            ...
# 8755      200002.0    2020.0   10/05/2020        Bethany
# 8756      200358.0    2020.0   07/12/2021      Killingly
# 8757      201259.0    2020.0   09/27/2021       Hartford
# 8758      200091.0    2020.0   05/27/2021        Bethany
# 8759       20726.0    2020.0   07/15/2021  East Hartford
#
#                              Address  AssessedValue   SaleAmount  SalesRatio  \
# 0                    230 WAKELEE AVE     15050000.0   32500000.0       463.0
# 1                    390 TURNPIKE RD     25300000.0   43000000.0      5883.0
# ...

# %%
dfTemp = dfData.isnull()
dfTemp.head(3)
# Out:
#    SerialNumber  ListYear  DateRecorded   Town  Address  AssessedValue  \
# 0         False     False         False  False    False          False
# 1         False     False         False  False    False          False
# 2         False     False         False  False    False          False
#
#    SaleAmount  SalesRatio  PropertyType  ResidentialType  NonUseCode  \
# 0       False       False         False             True        True
# 1       False       False         False            False        True
# 2       False       False         False            False        True
#
#    AssessorRemarks  OPMremarks
# 0             True        True
# 1             True        True
# 2             True        True

# %%
for clumn in dfTemp.columns.values.tolist():
    print(clumn)
    print(dfTemp[clumn].value_counts())
    print("")
# Out:
# SerialNumber
# False    199998
# Name: SerialNumber, dtype: int64
#
# ListYear
# False    199998
# Name: ListYear, dtype: int64
#
# DateRecorded
# False    199996
# True          2
# Name: DateRecorded, dtype: int64
#
# Town
# False    199998
# Name: Town, dtype: int64
#
# Address
# False    199994
# True          4
# Name: Address, dtype: int64
#
# AssessedValue
# False    199993
# True          5
# Name: AssessedValue, dtype: int64
#
# SaleAmount
# False    199993
# True          5
# Name: SaleAmount, dtype: int64
#
# SalesRatio
# False    199993
# True          5
# Name: SalesRatio, dtype: int64
#
# PropertyType
# True     133215
# False     66783
# Name: PropertyType, dtype: int64
#
# ResidentialType
# True     139063
# False     60935
# Name: ResidentialType, dtype: int64
#
# NonUseCode
# True     154251
# False     45747
# Name: NonUseCode, dtype: int64
#
# AssessorRemarks
# True     185654
# False     14344
# Name: AssessorRemarks, dtype: int64
#
# OPMremarks
# ...

# %%
dfData.describe()
# Out:
#        SerialNumber       ListYear  AssessedValue    SaleAmount    SalesRatio
# count  1.999980e+05  199998.000000   1.999930e+05  1.999930e+05  1.999930e+05
# mean   1.112861e+06    2007.821553   2.207152e+07  3.917854e+07  3.315238e+08
# std    1.273023e+07       8.655682   1.167706e+08  1.129725e+09  5.379511e+08
# min    0.000000e+00    2001.000000   0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.096800e+04    2001.000000   6.916100e+06  1.300000e+07  5.781000e+03
# 50%    2.040100e+04    2002.000000   1.098900e+07  2.150000e+07  3.260916e+08
# 75%    2.000610e+05    2020.000000   1.874300e+07  3.550000e+07  5.171552e+08
# max    2.000500e+09    2020.000000   1.149242e+10  5.000000e+11  9.999574e+09

# %%
dfData['SaleAmount'].sum()
# Out:
# 7835433956802.0

# %% [markdown]
# <h4 Style="color:#bac9a9"> Pregunta 1: Ingreso anual de propiedades vendidas</h4>

# %%
dfData['SaleAmount']= pd.to_numeric(dfData['SaleAmount'],errors='coerce')
ingresoanual=dfData.groupby('ListYear')['SaleAmount'].sum()
print(ingresoanual)
# Out:
# ListYear
# 2001.0    1.467167e+12
# 2002.0    1.710040e+12
# 2003.0    5.583694e+11
# 2004.0    3.810000e+07
# 2005.0    2.268956e+09
# 2006.0    6.370518e+09
# 2007.0    3.307944e+09
# 2008.0    2.310264e+09
# 2009.0    2.959803e+09
# 2010.0    4.502262e+09
# 2011.0    3.063695e+09
# 2012.0    3.962037e+09
# 2013.0    6.825809e+09
# 2014.0    7.573932e+09
# 2015.0    3.907227e+09
# 2016.0    3.096610e+09
# 2017.0    6.759359e+09
# 2018.0    1.001896e+10
# 2019.0    1.229586e+10
# 2020.0    4.020597e+12
# Name: SaleAmount, dtype: float64

# %%
import matplotlib as mpl
import seaborn as sns
mpl.rcParams["axes.spines.bottom"] = True
mpl.rcParams["axes.spines.left"] = False
mpl.rcParams["axes.spines.right"] = False
mpl.rcParams["axes.spines.top"] = False

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dfData['SaleAmount'] = pd.to_numeric(dfData['SaleAmount'], errors='coerce')
ingreso_anual = dfData.groupby('ListYear')['SaleAmount'].sum()

plt.figure(figsize=(8, 4)) 
ax = sns.barplot(x=ingreso_anual.index, y=ingreso_anual.values, color='#00c6ab')
plt.xlabel('Año')
plt.ylabel('Ingreso Anual')
plt.title('Ingreso Anual de Propiedades Vendidas')
plt.xticks(rotation=45) 
año_max_ingreso = ingreso_anual.idxmax()
ingreso_maximo = ingreso_anual.max()
index_max = ingreso_anual.index.get_loc(año_max_ingreso)
ax.text(index_max, ingreso_maximo + 10000, f'Max: {ingreso_maximo:.0f}', ha='center', va='bottom', fontsize=10, color='black')
plt.tight_layout() 
plt.show()

# %% [markdown]
# <p>En base a la informacion recopilada el año donde el ingreso anual de propiedades vendidas fue el mayor fue el 2020

# %% [markdown]
# <h4 Style="color:#bac9a9"> Pregunta 2: ¿Qué tipo de propiedad tiene mayor facilidad de venta?</h4>

# %%
profacilventa=dfData['PropertyType'].value_counts()
print(profacilventa)
# Out:
# Residential       60559
# Vacant Land        3156
# Commercial         1975
# Apartments          485
# Condo               371
# Industrial          227
# Public Utility        5
# Two Family            2
# Single Family         2
# Three Family          1
# Name: PropertyType, dtype: int64

# %%
profacilventa.plot(kind='bar')
plt.title('Propiedades facil venta')
plt.xlabel('Tipo de propiedades')# para colocar los nombres en x y y 
plt.ylabel('Cantidad')

plt.show()

# %% [markdown]
# <p>De acuerdo a la data recopilada el tipo de propiedad que tiene mayor facilidad de venta es Residencial, seguida de Vacant Land y Cpmmercial

# %% [markdown]
# <h4 Style="color:#bac9a9"> Pregunta 3: ¿En cuál ciudad o pueblo se dan mayor cantidad de ventas de propiedades? Y ¿Qué elementos particulares tienen esas ciudades o pueblos?</h4>

# %%
ciudad_mas_ventas = dfData['Town'].value_counts().idxmax()
cantidad_ventas_ciudad = dfData['Town'].value_counts().max()

total_ventas = len(dfData)

etiquetas = [ciudad_mas_ventas, 'other']
valores = [cantidad_ventas_ciudad, total_ventas - cantidad_ventas_ciudad]
plt.figure(figsize=(6, 6))
plt.pie(valores, labels=etiquetas, colors=['#3f8880', '#20c67a'], autopct='%1.1f%%', startangle=140)
plt.title(f'Proporción de Ventas en {ciudad_mas_ventas}')
plt.axis('equal') 
plt.show()

# %% [markdown]
# <p>Stamford es la ciudad donde se dan la mayor cantidad de ventas de propiedad , siendo en su mayoria propiedades tipo residencial y el tipo de residencia Single Family
